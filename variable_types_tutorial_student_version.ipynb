# %% [markdown]
# ***************
# STUDENT VERSION of Variable Types (Part 2.1 in tutorial)
# ***************
#
# The following notebook is a guideline for the exercises in Chapter 2,
# Section 2.1 of the Python tutorial.
#
# Please note that we provide partial solutions for a limited subset of variables;
# the remaining variables need to be explored by yourself. Also, some gaps in
# the code remain that you will need to fill (see ... #TODO statements).
#
# Press SHIFT + ENTER to run a cell.

# %% [markdown]
# ## EXERCISE 1:
# A university professor wishes to store the grades on individual assignments for each
# of the students enrolled in his course. He also maintains several characteristics of the students:
# age, major, minor, whether the student retook the course (retake), and whether the student has special needs (needs).
#
# The dictionary is called `grades`, where keys correspond to student names (strings)
# and the associated values are tuples `t`:
# `t = (age, major, minor, retake, needs, grades_list)`, where:
# - `age` is an integer
# - `major` and `minor` are strings
# - `retake` and `needs` are booleans (`True` or `False`)
# - `grades_list` is a list of integers (0-20)
#
# Construct a `grades` dictionary with the following students:
#
# - **Kevin G.**: age = 20, major = Mathematics, minor = Finance, retake = False, needs = False, grades = [15, 17, 16]
# - **Steven V.**: age = 21, major = International Business, minor = Logistics, retake = False, needs = True, grades = [2, 5, 1]
# - **Dave L.**: age = 22, major = Strategy & Organization, minor = Accounting, retake = True, needs = False, grades = [10, 13, 12]
# - **Kate M.**: age = 20, major = Computer Science, minor = Electrical Engineering, retake = False, needs = False, grades = [15, 16, 14]
# - **Dennis P.**: age = 21, major = Data Science, minor = Finance, retake = False, needs = False, grades = [14, 16, 16]
# - **Laura A.**: age = 21, major = Data Science, minor = Strategy & Organization, retake = False, needs = True, grades = [14, 15, 17]

# %%
# Construct the grades dictionary
grades = ... #TODO

# %% [markdown]
# ## EXERCISE 2:
# Access the grades of students Dennis P. and Steven V. (print them out on the screen).

# %%
print('The grades of Dennis P. are: ', ...) #TODO
print('The grades of Steven V. are: ', ... ) #TODO
# Out:
# The grades of Dennis P. are:  Ellipsis
# The grades of Steven V. are:  Ellipsis

# %% [markdown]
# ## EXERCISE 3:
# Calculate the average grade for students Dennis P. and Steven V.
# For now, assume only 3 grades are in the grades list.

# %%
grades_dennis_p = ... #TODO
avg_grade_dennis_p = ... #TODO (grade_1 + grade_2 + grade_3) / number_of_grades
print('The average grade of Dennis P. is: ', avg_grade_dennis_p)

grades_steven_v = ... #TODO
avg_grade_steven_v  = ... #TODO (grade_1 + grade_2 + grade_3) / number_of_grades
print('The average grade of Steven V. is: ', avg_grade_steven_v )

# %% [markdown]
# ## EXERCISE 4:
# Construct a variable `name` to store a single student of interest's name.
# Next, print the following string 'Student name has major as major and minor as minor'.
# (`name` should be the value in the variable name and major/minor should be accessed from Grades).

# %%
name = 'Kevin G.' # modify this if you want
print(...) #TODO - make use of the format function like: print(TODO.format(TODO))
print(...) #TODO alternative, make use of string concatenation with the + operator

# %% [markdown]
# ## EXERCISE 5:
# Print out the name (defined previously) and the grades of the student on a single line as follows:
# Student name has grades [...,....,...]
# Use f strings or string concatenation with the + operator.

# %%
print(...) #TODO
print(...) #TODO alternative, use of + operator

# %% [markdown]
# ## EXERCISE 6:
# Add to the `grades` dictionary a new student with the following characteristics:
#    - name = Kurt H. ; Age = 22 ; major = 'Accounting' ; minor = 'Logistics' ;
#    retake = True ; needs = False ; Grades = [14, 13, 13]

# %%
... #TODO
print('Kurt H. has the following characteristics: ', grades['Kurt H.'])

# %% [markdown]
# ## EXERCISE 7:
# Student Dave L. took a new test and scored 14/20.
# Add this grade to the dictionary (at the end of its grade list) and verify whether it is indeed modified.

# %%
... #TODO
print('Dave L. has the following characteristics: ', grades['Dave L.'])
